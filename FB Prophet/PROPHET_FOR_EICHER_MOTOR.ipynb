# %%
import pandas as pd

# %%
df=pd.read_csv('/content/EICHERMOT.NS.csv')

# %%
df
# Out:
#             Data         Open         High          Low        Close  \
# 0     2018-01-01  3039.995117  3042.000000  2985.000000  2989.314941
# 1     2018-01-02  2992.500000  2995.500000  2853.969971  2867.014893
# 2     2018-01-03  2885.000000  2904.500000  2854.215088  2881.435059
# 3     2018-01-04  2882.570068  2895.760010  2841.500000  2857.074951
# 4     2018-01-05  2879.699951  2932.500000  2868.620117  2923.699951
# ...          ...          ...          ...          ...          ...
# 1231  2022-12-26  3115.000000  3228.649902  3088.199951  3161.250000
# 1232  2022-12-27  3174.949951  3213.149902  3150.000000  3201.800049
# 1233  2022-12-28  3188.149902  3233.600098  3175.600098  3211.550049
# 1234  2022-12-29  3181.050049  3490.750000  3163.250000  3281.199951
# 1235  2022-12-30  3290.000000  3298.000000  3217.250000  3227.750000
#
#         Adj Close  Volume
# 0     2674.030518  198470
# 1     2564.629883  847930
# 2     2577.529053  470880
# 3     2555.737793  494210
# ...

# %%
import plotly.express as px

# %%
fig=px.line(df, x="Data", y="Close")
fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install pystan~=2.14
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install fbprophet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
from prophet import Prophet

# %%
import numpy as np, matplotlib.pyplot as plt

# %%
df= df[["Data", "Close"]]

# %%
df
# Out:
#             Data        Close
# 0     2018-01-01  2989.314941
# 1     2018-01-02  2867.014893
# 2     2018-01-03  2881.435059
# 3     2018-01-04  2857.074951
# 4     2018-01-05  2923.699951
# ...          ...          ...
# 1231  2022-12-26  3161.250000
# 1232  2022-12-27  3201.800049
# 1233  2022-12-28  3211.550049
# 1234  2022-12-29  3281.199951
# 1235  2022-12-30  3227.750000
#
# [1236 rows x 2 columns]

# %%
new_df=df[["Data", "Close"]]
new_df["Data"]=pd.to_datetime(new_df["Data"])
new_df.rename(columns = {"Data":"ds"}, inplace = True)
new_df.rename(columns = {"Close":"y"}, inplace = True)

# %%
m = Prophet(daily_seasonality=True)
m.fit(new_df)

# %%
from fbprophet import Prophet

# %%
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)

# %%
pd.options.display.max_columns = None
print(forecast.tail(365))
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 1236 2022-12-31  3651.210920  3460.988722  3870.250118  3651.210920
# 1237 2023-01-01  3653.938577  3555.357005  3963.245555  3653.938577
# 1238 2023-01-02  3656.666235  3394.417957  3811.950932  3656.666235
# 1239 2023-01-03  3659.393892  3411.720348  3816.947010  3659.393892
# 1240 2023-01-04  3662.121550  3412.387714  3823.751870  3662.121550
# ...         ...          ...          ...          ...          ...
# 1596 2023-12-26  4633.167629  3714.371857  5275.072601  3924.377876
# 1597 2023-12-27  4635.895286  3802.860064  5232.939298  3925.767666
# 1598 2023-12-28  4638.622944  3801.507833  5296.831570  3926.969360
# 1599 2023-12-29  4641.350601  3804.935516  5310.972146  3926.252959
# 1600 2023-12-30  4644.078259  3860.748222  5412.860812  3925.536559
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']])
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 0    2018-01-01  2877.874151  2660.640167  3082.331247
# 1    2018-01-02  2891.634487  2679.508083  3093.840960
# 2    2018-01-03  2894.066680  2676.639900  3094.620244
# 3    2018-01-04  2908.857395  2705.545152  3129.842577
# 4    2018-01-05  2910.479177  2708.549935  3127.152448
# ...         ...          ...          ...          ...
# 1596 2023-12-26  4530.281569  3714.371857  5275.072601
# 1597 2023-12-27  4535.624070  3802.860064  5232.939298
# 1598 2023-12-28  4554.165925  3801.507833  5296.831570
# 1599 2023-12-29  4560.275211  3804.935516  5310.972146
# 1600 2023-12-30  4648.677592  3860.748222  5412.860812
#
# [1601 rows x 4 columns]

# %%
from prophet.plot import plot_plotly
plot_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
